# %%
import gc
import os
from datetime import datetime
import pickle
import psutil
from tqdm import tqdm, tqdm_notebook
from functools import partial, update_wrapper
from itertools import product
from multiprocessing import Pool

import bloscpack as bp

import random
import numpy as np
import pandas as pd
from sklearn.preprocessing import normalize
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler

from YSMLT import utils as g_utils
from YSMLT.series import utils as ts_utils

from scipy.signal import hilbert
from scipy.signal import hann
from scipy.signal import convolve
from scipy.signal import welch, find_peaks
from scipy import stats
from scipy.special import entr
from scipy.stats import entropy
from tsfresh.feature_extraction import feature_calculators

# %% [markdown]
# ### mean -0.31079195780498403
# ### std  2.4983141023158186

# %%
pdf_trn = pd.read_csv('../input/train_clean.csv')
pdf_tst = pd.read_csv('../input/test_clean.csv')

with open('../input/batch_ids_trn.pkl', 'rb') as f:
    batch_id_trn = pickle.load(f)
with open('../input/batch_ids_tst.pkl', 'rb') as f:
    batch_id_tst = pickle.load(f)

# %%
step = 500
wndw = 500
# fill = -0.31079195780498403

# %% [raw]
# a = np.arange(500000)
# b = ts_utils.serie_stacker(pd.Series(a), step_size=step, block_size=wndw)

# %% [raw]
# scaler = MinMaxScaler(feature_range=(-1, 1))
#
# def scale(srs):
#     if isinstance(srs, pd.Series):
#         reshaped_arr = srs.values.reshape(-1, 1)
#     elif isinstance(srs, np.ndarray):
#         reshaped_arr = srs.reshape(-1, 1)
#     transformed_arr = scaler.fit_transform(reshaped_arr).squeeze()
#     return pd.Series(transformed_arr)

# %% [raw]
# no_zero = lambda x: np.where(x == 0, 1e-6, x)

# %%
for i in tqdm(range(0, 10)):
    sgnl_ndcs = batch_id_trn[i]
    
    trgt = pdf_trn['open_channels'].iloc[sgnl_ndcs]
    
    # ------------------------------------------------
    sgnl_p1 = pdf_trn['signal'].iloc[sgnl_ndcs]
    p1_fill = sgnl_p1.mean()
    
    sgnl_p1b5 = sgnl_p1.shift(-5, fill_value=p1_fill)
    sgnl_p1b4 = sgnl_p1.shift(-4, fill_value=p1_fill)
    sgnl_p1b3 = sgnl_p1.shift(-3, fill_value=p1_fill)
    sgnl_p1b2 = sgnl_p1.shift(-2, fill_value=p1_fill)
    sgnl_p1b1 = sgnl_p1.shift(-1, fill_value=p1_fill)
    sgnl_p1f1 = sgnl_p1.shift(1, fill_value=p1_fill)
    sgnl_p1f2 = sgnl_p1.shift(2, fill_value=p1_fill)
    sgnl_p1f3 = sgnl_p1.shift(3, fill_value=p1_fill)
    sgnl_p1f4 = sgnl_p1.shift(4, fill_value=p1_fill)
    sgnl_p1f5 = sgnl_p1.shift(5, fill_value=p1_fill)

    sr_p1b5 = ts_utils.serie_stacker(sgnl_p1b5, step_size=step, block_size=wndw)
    sr_p1b4 = ts_utils.serie_stacker(sgnl_p1b4, step_size=step, block_size=wndw)
    sr_p1b3 = ts_utils.serie_stacker(sgnl_p1b3, step_size=step, block_size=wndw)
    sr_p1b2 = ts_utils.serie_stacker(sgnl_p1b2, step_size=step, block_size=wndw)
    sr_p1b1 = ts_utils.serie_stacker(sgnl_p1b1, step_size=step, block_size=wndw)
    sr_p1  = ts_utils.serie_stacker(sgnl_p1, step_size=step, block_size=wndw)
    sr_p1f1 = ts_utils.serie_stacker(sgnl_p1f1, step_size=step, block_size=wndw)
    sr_p1f2 = ts_utils.serie_stacker(sgnl_p1f2, step_size=step, block_size=wndw)
    sr_p1f3 = ts_utils.serie_stacker(sgnl_p1f3, step_size=step, block_size=wndw)
    sr_p1f4 = ts_utils.serie_stacker(sgnl_p1f4, step_size=step, block_size=wndw)
    sr_p1f5 = ts_utils.serie_stacker(sgnl_p1f5, step_size=step, block_size=wndw)
    
    # ------------------------------------------------
    sgnl_p2 = sgnl_p1**2
    p2_fill = sgnl_p2.mean()
    
    sgnl_p2b5 = sgnl_p2.shift(-5, fill_value=p2_fill)
    sgnl_p2b4 = sgnl_p2.shift(-4, fill_value=p2_fill)
    sgnl_p2b3 = sgnl_p2.shift(-3, fill_value=p2_fill)
    sgnl_p2b2 = sgnl_p2.shift(-2, fill_value=p2_fill)
    sgnl_p2b1 = sgnl_p2.shift(-1, fill_value=p2_fill)
    sgnl_p2f1 = sgnl_p2.shift(1, fill_value=p2_fill)
    sgnl_p2f2 = sgnl_p2.shift(2, fill_value=p2_fill)
    sgnl_p2f3 = sgnl_p2.shift(3, fill_value=p2_fill)
    sgnl_p2f4 = sgnl_p2.shift(4, fill_value=p2_fill)
    sgnl_p2f5 = sgnl_p2.shift(5, fill_value=p2_fill)
    
    sr_p2b5 = ts_utils.serie_stacker(sgnl_p2b5, step_size=step, block_size=wndw)
    sr_p2b4 = ts_utils.serie_stacker(sgnl_p2b4, step_size=step, block_size=wndw)
    sr_p2b3 = ts_utils.serie_stacker(sgnl_p2b3, step_size=step, block_size=wndw)
    sr_p2b2 = ts_utils.serie_stacker(sgnl_p2b2, step_size=step, block_size=wndw)
    sr_p2b1 = ts_utils.serie_stacker(sgnl_p2b1, step_size=step, block_size=wndw)
    sr_p2  = ts_utils.serie_stacker(sgnl_p2, step_size=step, block_size=wndw)
    sr_p2f1 = ts_utils.serie_stacker(sgnl_p2f1, step_size=step, block_size=wndw)
    sr_p2f2 = ts_utils.serie_stacker(sgnl_p2f2, step_size=step, block_size=wndw)
    sr_p2f3 = ts_utils.serie_stacker(sgnl_p2f3, step_size=step, block_size=wndw)
    sr_p2f4 = ts_utils.serie_stacker(sgnl_p2f4, step_size=step, block_size=wndw)
    sr_p2f5 = ts_utils.serie_stacker(sgnl_p2f5, step_size=step, block_size=wndw)
    
    sr = np.stack(
        [
            sr_p1, 
            sr_p1b5, sr_p1b4, sr_p1b3, sr_p1b2, sr_p1b1, sr_p1f1, sr_p1f2, sr_p1f3, sr_p1f4, sr_p1f5,
            sr_p2, 
            sr_p2b5, sr_p2b4, sr_p2b3, sr_p2b2, sr_p2b1, sr_p2f1, sr_p2f2, sr_p2f3, sr_p2f4, sr_p2f5,
        ],
        axis=2
    )
    
    tr = ts_utils.serie_stacker(trgt, step_size=step, block_size=wndw)
    
    bp.pack_ndarray_to_file(sr, '../input/trn_srs_dat_g{:d}_s{:d}_w{:d}_feat_basic.bp'.format(i, step, wndw))
    bp.pack_ndarray_to_file(tr, '../input/trn_srs_lbl_g{:d}_s{:d}_w{:d}_feat_basic.bp'.format(i, step, wndw))
    
    del sgnl_ndcs
    
    del sgnl_p1, sgnl_p2
    del sgnl_p1b5, sgnl_p1b4, sgnl_p1b3, sgnl_p1b2, sgnl_p1b1, sgnl_p1f1, sgnl_p1f2, sgnl_p1f3, sgnl_p1f4, sgnl_p1f5
    del sgnl_p2b5, sgnl_p2b4, sgnl_p2b3, sgnl_p2b2, sgnl_p2b1, sgnl_p2f1, sgnl_p2f2, sgnl_p2f3, sgnl_p2f4, sgnl_p2f5
    
    del trgt
    
    del sr_p1
    del sr_p1b5, sr_p1b4, sr_p1b3, sr_p1b2, sr_p1b1, sr_p1f1, sr_p1f2, sr_p1f3, sr_p1f4, sr_p1f5
    del sr_p2
    del sr_p2b5, sr_p2b4, sr_p2b3, sr_p2b2, sr_p2b1, sr_p2f1, sr_p2f2, sr_p2f3, sr_p2f4, sr_p2f5
    del sr, tr
# Out:
# 100%|██████████| 10/10 [00:06<00:00,  1.46it/s]

# %%
for i in tqdm(range(0, 20)):
    sgnl_ndcs = batch_id_tst[i]
    
    # ------------------------------------------------
    sgnl_p1 = pdf_tst['signal'].iloc[sgnl_ndcs]
    p1_fill = sgnl_p1.mean()
    
    sgnl_p1b5 = sgnl_p1.shift(-5, fill_value=p1_fill)
    sgnl_p1b4 = sgnl_p1.shift(-4, fill_value=p1_fill)
    sgnl_p1b3 = sgnl_p1.shift(-3, fill_value=p1_fill)
    sgnl_p1b2 = sgnl_p1.shift(-2, fill_value=p1_fill)
    sgnl_p1b1 = sgnl_p1.shift(-1, fill_value=p1_fill)
    sgnl_p1f1 = sgnl_p1.shift(1, fill_value=p1_fill)
    sgnl_p1f2 = sgnl_p1.shift(2, fill_value=p1_fill)
    sgnl_p1f3 = sgnl_p1.shift(3, fill_value=p1_fill)
    sgnl_p1f4 = sgnl_p1.shift(4, fill_value=p1_fill)
    sgnl_p1f5 = sgnl_p1.shift(5, fill_value=p1_fill)
    
    sr_p1b5 = ts_utils.serie_stacker(sgnl_p1b5, step_size=step, block_size=wndw)
    sr_p1b4 = ts_utils.serie_stacker(sgnl_p1b4, step_size=step, block_size=wndw)
    sr_p1b3 = ts_utils.serie_stacker(sgnl_p1b3, step_size=step, block_size=wndw)
    sr_p1b2 = ts_utils.serie_stacker(sgnl_p1b2, step_size=step, block_size=wndw)
    sr_p1b1 = ts_utils.serie_stacker(sgnl_p1b1, step_size=step, block_size=wndw)
    sr_p1  = ts_utils.serie_stacker(sgnl_p1, step_size=step, block_size=wndw)
    sr_p1f1 = ts_utils.serie_stacker(sgnl_p1f1, step_size=step, block_size=wndw)
    sr_p1f2 = ts_utils.serie_stacker(sgnl_p1f2, step_size=step, block_size=wndw)
    sr_p1f3 = ts_utils.serie_stacker(sgnl_p1f3, step_size=step, block_size=wndw)
    sr_p1f4 = ts_utils.serie_stacker(sgnl_p1f4, step_size=step, block_size=wndw)
    sr_p1f5 = ts_utils.serie_stacker(sgnl_p1f5, step_size=step, block_size=wndw)
    
    # ------------------------------------------------
    sgnl_p2 = sgnl_p1**2
    p2_fill = sgnl_p2.mean()
    
    sgnl_p2b5 = sgnl_p2.shift(-5, fill_value=p2_fill)
    sgnl_p2b4 = sgnl_p2.shift(-4, fill_value=p2_fill)
    sgnl_p2b3 = sgnl_p2.shift(-3, fill_value=p2_fill)
    sgnl_p2b2 = sgnl_p2.shift(-2, fill_value=p2_fill)
    sgnl_p2b1 = sgnl_p2.shift(-1, fill_value=p2_fill)
    sgnl_p2f1 = sgnl_p2.shift(1, fill_value=p2_fill)
    sgnl_p2f2 = sgnl_p2.shift(2, fill_value=p2_fill)
    sgnl_p2f3 = sgnl_p2.shift(3, fill_value=p2_fill)
    sgnl_p2f4 = sgnl_p2.shift(4, fill_value=p2_fill)
    sgnl_p2f5 = sgnl_p2.shift(5, fill_value=p2_fill)
    
    sr_p2b5 = ts_utils.serie_stacker(sgnl_p2b5, step_size=step, block_size=wndw)
    sr_p2b4 = ts_utils.serie_stacker(sgnl_p2b4, step_size=step, block_size=wndw)
    sr_p2b3 = ts_utils.serie_stacker(sgnl_p2b3, step_size=step, block_size=wndw)
    sr_p2b2 = ts_utils.serie_stacker(sgnl_p2b2, step_size=step, block_size=wndw)
    sr_p2b1 = ts_utils.serie_stacker(sgnl_p2b1, step_size=step, block_size=wndw)
    sr_p2  = ts_utils.serie_stacker(sgnl_p2, step_size=step, block_size=wndw)
    sr_p2f1 = ts_utils.serie_stacker(sgnl_p2f1, step_size=step, block_size=wndw)
    sr_p2f2 = ts_utils.serie_stacker(sgnl_p2f2, step_size=step, block_size=wndw)
    sr_p2f3 = ts_utils.serie_stacker(sgnl_p2f3, step_size=step, block_size=wndw)
    sr_p2f4 = ts_utils.serie_stacker(sgnl_p2f4, step_size=step, block_size=wndw)
    sr_p2f5 = ts_utils.serie_stacker(sgnl_p2f5, step_size=step, block_size=wndw)

    sr = np.stack(
        [
            sr_p1, 
            sr_p1b5, sr_p1b4, sr_p1b3, sr_p1b2, sr_p1b1, sr_p1f1, sr_p1f2, sr_p1f3, sr_p1f4, sr_p1f5,
            sr_p2, 
            sr_p2b5, sr_p2b4, sr_p2b3, sr_p2b2, sr_p2b1, sr_p2f1, sr_p2f2, sr_p2f3, sr_p2f4, sr_p2f5,
        ],
        axis=2
    )
    
    bp.pack_ndarray_to_file(sr, '../input/tst_srs_dat_g{:d}_s{:d}_w{:d}_feat_basic.bp'.format(i, step, wndw))
    
    del sgnl_ndcs
    
    del sgnl_p1, sgnl_p2
    del sgnl_p1b5, sgnl_p1b4, sgnl_p1b3, sgnl_p1b2, sgnl_p1b1, sgnl_p1f1, sgnl_p1f2, sgnl_p1f3, sgnl_p1f4, sgnl_p1f5
    del sgnl_p2b5, sgnl_p2b4, sgnl_p2b3, sgnl_p2b2, sgnl_p2b1, sgnl_p2f1, sgnl_p2f2, sgnl_p2f3, sgnl_p2f4, sgnl_p2f5
    
    del sr_p1
    del sr_p1b5, sr_p1b4, sr_p1b3, sr_p1b2, sr_p1b1, sr_p1f1, sr_p1f2, sr_p1f3, sr_p1f4, sr_p1f5
    del sr_p2
    del sr_p2b5, sr_p2b4, sr_p2b3, sr_p2b2, sr_p2b1, sr_p2f1, sr_p2f2, sr_p2f3, sr_p2f4, sr_p2f5
    del sr
# Out:
# 100%|██████████| 20/20 [00:02<00:00,  8.96it/s]

# %% [raw]
# for i in tqdm(range(0, 10)):
#     sgnl_ndcs = batch_id_trn[i]
#
#     trgt = pdf_trn['open_channels'].iloc[sgnl_ndcs]
#
#     # ------------------------------------------------
#     sgnl_p1 = pdf_trn['signal_norm'].iloc[sgnl_ndcs]
#
#     sgnl_p1b5 = sgnl_p1.shift(-5, fill_value=fill)
#     sgnl_p1b4 = sgnl_p1.shift(-4, fill_value=fill)
#     sgnl_p1b3 = sgnl_p1.shift(-3, fill_value=fill)
#     sgnl_p1b2 = sgnl_p1.shift(-2, fill_value=fill)
#     sgnl_p1b1 = sgnl_p1.shift(-1, fill_value=fill)
#     sgnl_p1f1 = sgnl_p1.shift(1, fill_value=fill)
#     sgnl_p1f2 = sgnl_p1.shift(2, fill_value=fill)
#     sgnl_p1f3 = sgnl_p1.shift(3, fill_value=fill)
#     sgnl_p1f4 = sgnl_p1.shift(4, fill_value=fill)
#     sgnl_p1f5 = sgnl_p1.shift(5, fill_value=fill)
#
#     sgnl_stck0 = np.stack([sgnl_p1b5, sgnl_p1b4, sgnl_p1b3, sgnl_p1b2, sgnl_p1b1, sgnl_p1, sgnl_p1f1, sgnl_p1f2, sgnl_p1f3, sgnl_p1f4, sgnl_p1f5])
#     sgnl_stckb = np.stack([sgnl_p1b5, sgnl_p1b4, sgnl_p1b3, sgnl_p1b2, sgnl_p1b1])
#     sgnl_stckf = np.stack([sgnl_p1f1, sgnl_p1f2, sgnl_p1f3, sgnl_p1f4, sgnl_p1f5])
#
#     sgnl_std = scale(np.std(sgnl_stck0, 0))
#     sgnl_med = scale(np.median(sgnl_stck0, 0))
#     sgnl_q10 = scale(np.quantile(sgnl_stck0, 0.1, 0))
#     sgnl_q90 = scale(np.quantile(sgnl_stck0, 0.9, 0))
#     sgnl_fb_ratio0 = scale(sgnl_stckf.sum(0) / sgnl_stckb.sum(0))
#     sgnl_fb_ratio1 = scale(np.max(sgnl_stckf, 0) / np.max(sgnl_stckb, 0))
#     sgnl_fb_ratio2 = scale(np.max(sgnl_stckf, 0) / np.min(sgnl_stckb, 0))
#     sgnl_fb_ratio3 = scale(np.min(sgnl_stckf, 0) / np.max(sgnl_stckb, 0))
#     sgnl_fb_ratio4 = scale(np.median(sgnl_stckf, 0) / np.median(sgnl_stckb, 0))
#     sgnl_fb_ratio5 = scale(np.quantile(sgnl_stckf, 0.1, 0) / np.quantile(sgnl_stckb, 0.1, 0))
#     sgnl_fb_ratio6 = scale(np.quantile(sgnl_stckf, 0.9, 0) / np.quantile(sgnl_stckb, 0.9, 0))
#     sgnl_fb_ratio7 = scale(np.quantile(sgnl_stckf, 0.9, 0) / np.quantile(sgnl_stckb, 0.1, 0))
#     sgnl_fb_ratio8 = scale(np.quantile(sgnl_stckf, 0.1, 0) / np.quantile(sgnl_stckb, 0.9, 0))
#
#     sr_p1b5 = ts_utils.serie_stacker(scale(sgnl_p1b5), step_size=step, block_size=wndw)
#     sr_p1b4 = ts_utils.serie_stacker(scale(sgnl_p1b4), step_size=step, block_size=wndw)
#     sr_p1b3 = ts_utils.serie_stacker(scale(sgnl_p1b3), step_size=step, block_size=wndw)
#     sr_p1b2 = ts_utils.serie_stacker(scale(sgnl_p1b2), step_size=step, block_size=wndw)
#     sr_p1b1 = ts_utils.serie_stacker(scale(sgnl_p1b1), step_size=step, block_size=wndw)
#     sr_p1  = ts_utils.serie_stacker(scale(sgnl_p1), step_size=step, block_size=wndw)
#     sr_p1f1 = ts_utils.serie_stacker(scale(sgnl_p1f1), step_size=step, block_size=wndw)
#     sr_p1f2 = ts_utils.serie_stacker(scale(sgnl_p1f2), step_size=step, block_size=wndw)
#     sr_p1f3 = ts_utils.serie_stacker(scale(sgnl_p1f3), step_size=step, block_size=wndw)
#     sr_p1f4 = ts_utils.serie_stacker(scale(sgnl_p1f4), step_size=step, block_size=wndw)
#     sr_p1f5 = ts_utils.serie_stacker(scale(sgnl_p1f5), step_size=step, block_size=wndw)
#
#     sr_p1_b3f3_b2f2_b1f1  = ts_utils.serie_stacker(
#         scale(sgnl_p1b3*sgnl_p1f3+sgnl_p1b2*sgnl_p1f2+sgnl_p1b1*sgnl_p1f1),
#         step_size=step,
#         block_size=wndw
#     )
#
#     sr_p1_b3f1_b2f2_b1f3  = ts_utils.serie_stacker(
#         scale(sgnl_p1b3*sgnl_p1f1-sgnl_p1b2*sgnl_p1f2+sgnl_p1b1*sgnl_p1f3),
#         step_size=step,
#         block_size=wndw
#     )
#
#     sr_p1std = ts_utils.serie_stacker(sgnl_std, step_size=step, block_size=wndw)
#     sr_p1med = ts_utils.serie_stacker(sgnl_med, step_size=step, block_size=wndw)
#     sr_p1q10 = ts_utils.serie_stacker(sgnl_q10, step_size=step, block_size=wndw)
#     sr_p1q90 = ts_utils.serie_stacker(sgnl_q90, step_size=step, block_size=wndw)
#     sr_p1fbr0 = ts_utils.serie_stacker(sgnl_fb_ratio0, step_size=step, block_size=wndw)
#     sr_p1fbr1 = ts_utils.serie_stacker(sgnl_fb_ratio1, step_size=step, block_size=wndw)
#     sr_p1fbr2 = ts_utils.serie_stacker(sgnl_fb_ratio2, step_size=step, block_size=wndw)
#     sr_p1fbr3 = ts_utils.serie_stacker(sgnl_fb_ratio3, step_size=step, block_size=wndw)
#     sr_p1fbr4 = ts_utils.serie_stacker(sgnl_fb_ratio4, step_size=step, block_size=wndw)
#     sr_p1fbr5 = ts_utils.serie_stacker(sgnl_fb_ratio5, step_size=step, block_size=wndw)
#     sr_p1fbr6 = ts_utils.serie_stacker(sgnl_fb_ratio6, step_size=step, block_size=wndw)
#     sr_p1fbr7 = ts_utils.serie_stacker(sgnl_fb_ratio7, step_size=step, block_size=wndw)
#     sr_p1fbr8 = ts_utils.serie_stacker(sgnl_fb_ratio8, step_size=step, block_size=wndw)
#
#     # ------------------------------------------------
#     sgnl_p2 = sgnl_p1**2
#
#     sgnl_p2b5 = sgnl_p2.shift(-5, fill_value=fill)
#     sgnl_p2b4 = sgnl_p2.shift(-4, fill_value=fill)
#     sgnl_p2b3 = sgnl_p2.shift(-3, fill_value=fill)
#     sgnl_p2b2 = sgnl_p2.shift(-2, fill_value=fill)
#     sgnl_p2b1 = sgnl_p2.shift(-1, fill_value=fill)
#     sgnl_p2f1 = sgnl_p2.shift(1, fill_value=fill)
#     sgnl_p2f2 = sgnl_p2.shift(2, fill_value=fill)
#     sgnl_p2f3 = sgnl_p2.shift(3, fill_value=fill)
#     sgnl_p2f4 = sgnl_p2.shift(4, fill_value=fill)
#     sgnl_p2f5 = sgnl_p2.shift(5, fill_value=fill)
#
#     sr_p2b5 = ts_utils.serie_stacker(scale(sgnl_p2b5), step_size=step, block_size=wndw)
#     sr_p2b4 = ts_utils.serie_stacker(scale(sgnl_p2b4), step_size=step, block_size=wndw)
#     sr_p2b3 = ts_utils.serie_stacker(scale(sgnl_p2b3), step_size=step, block_size=wndw)
#     sr_p2b2 = ts_utils.serie_stacker(scale(sgnl_p2b2), step_size=step, block_size=wndw)
#     sr_p2b1 = ts_utils.serie_stacker(scale(sgnl_p2b1), step_size=step, block_size=wndw)
#     sr_p2  = ts_utils.serie_stacker(scale(sgnl_p2), step_size=step, block_size=wndw)
#     sr_p2f1 = ts_utils.serie_stacker(scale(sgnl_p2f1), step_size=step, block_size=wndw)
#     sr_p2f2 = ts_utils.serie_stacker(scale(sgnl_p2f2), step_size=step, block_size=wndw)
#     sr_p2f3 = ts_utils.serie_stacker(scale(sgnl_p2f3), step_size=step, block_size=wndw)
#     sr_p2f4 = ts_utils.serie_stacker(scale(sgnl_p2f4), step_size=step, block_size=wndw)
#     sr_p2f5 = ts_utils.serie_stacker(scale(sgnl_p2f5), step_size=step, block_size=wndw)
#
#     sr_p1b5_p2f5 = ts_utils.serie_stacker(scale((sgnl_p1b5+sgnl_p2f5)/sgnl_p2), step_size=step, block_size=wndw)
#     sr_p1b3_p2f3 = ts_utils.serie_stacker(scale((sgnl_p1b3+sgnl_p2f3)/sgnl_p2), step_size=step, block_size=wndw)
#     sr_p1b1_p2f1 = ts_utils.serie_stacker(scale((sgnl_p1b1+sgnl_p2f1)/sgnl_p2), step_size=step, block_size=wndw)
#     sr_p1f1_p2b1 = ts_utils.serie_stacker(scale((sgnl_p1f1-sgnl_p2b1)/sgnl_p2), step_size=step, block_size=wndw)
#     sr_p1f3_p2b3 = ts_utils.serie_stacker(scale((sgnl_p1f3-sgnl_p2b3)/sgnl_p2), step_size=step, block_size=wndw)
#     sr_p1f5_p2b5 = ts_utils.serie_stacker(scale((sgnl_p1f5-sgnl_p2b5)/sgnl_p2), step_size=step, block_size=wndw)
#
#     sr_p2b5_p1favg = ts_utils.serie_stacker(scale(sgnl_p2b5-sgnl_stckf.mean(0)), step_size=step, block_size=wndw)
#     sr_p2b3_p1favg = ts_utils.serie_stacker(scale(sgnl_p2b3-sgnl_stckf.mean(0)), step_size=step, block_size=wndw)
#     sr_p2b1_p1favg = ts_utils.serie_stacker(scale(sgnl_p2b1-sgnl_stckf.mean(0)), step_size=step, block_size=wndw)
#     sr_p2f5_p1bavg = ts_utils.serie_stacker(scale(sgnl_p2f5-sgnl_stckb.mean(0)), step_size=step, block_size=wndw)
#     sr_p2f3_p1bavg = ts_utils.serie_stacker(scale(sgnl_p2f3-sgnl_stckb.mean(0)), step_size=step, block_size=wndw)
#     sr_p2f1_p1bavg = ts_utils.serie_stacker(scale(sgnl_p2f1-sgnl_stckb.mean(0)), step_size=step, block_size=wndw)
#     #break
#     sr = np.stack(
#         [
#             sr_p1,
#             sr_p1b5, sr_p1b4, sr_p1b3, sr_p1b2, sr_p1b1, sr_p1f1, sr_p1f2, sr_p1f3, sr_p1f4, sr_p1f5,
#             sr_p1std, sr_p1med, sr_p1q10, sr_p1q90,
#             sr_p1fbr0, sr_p1fbr1, sr_p1fbr2, sr_p1fbr3, sr_p1fbr4, sr_p1fbr5, sr_p1fbr6, sr_p1fbr7, sr_p1fbr8,
#             sr_p1_b3f3_b2f2_b1f1, sr_p1_b3f1_b2f2_b1f3,
#             sr_p2,
#             sr_p2b5, sr_p2b4, sr_p2b3, sr_p2b2, sr_p2b1, sr_p2f1, sr_p2f2, sr_p2f3, sr_p2f4, sr_p2f5,
#             sr_p1b5_p2f5, sr_p1b3_p2f3, sr_p1b1_p2f1, sr_p1f1_p2b1, sr_p1f3_p2b3, sr_p1f5_p2b5,
#             sr_p2b5_p1favg, sr_p2b3_p1favg, sr_p2b1_p1favg, sr_p2f5_p1bavg, sr_p2f3_p1bavg, sr_p2f1_p1bavg,
#         ],
#         axis=2
#     )
#
#     tr = ts_utils.serie_stacker(trgt, step_size=step, block_size=wndw)
#
#     bp.pack_ndarray_to_file(sr, '../input/trn_srs_dat_g{:d}_s{:d}_w{:d}_feat_v1.bp'.format(i, step, wndw))
#     bp.pack_ndarray_to_file(tr, '../input/trn_srs_lbl_g{:d}_s{:d}_w{:d}_feat_v1.bp'.format(i, step, wndw))
#
#     del sgnl_ndcs
#
#     del sgnl_p1, sgnl_p2
#     del sgnl_p1b5, sgnl_p1b4, sgnl_p1b3, sgnl_p1b2, sgnl_p1b1, sgnl_p1f1, sgnl_p1f2, sgnl_p1f3, sgnl_p1f4, sgnl_p1f5
#     del sgnl_stck0
#     del sgnl_stckb, sgnl_stckf
#     del sgnl_std, sgnl_med, sgnl_q10, sgnl_q90
#     del sgnl_fb_ratio0, sgnl_fb_ratio1, sgnl_fb_ratio2, sgnl_fb_ratio3, sgnl_fb_ratio4, sgnl_fb_ratio5, sgnl_fb_ratio6, sgnl_fb_ratio7, sgnl_fb_ratio8
#     del sgnl_p2b5, sgnl_p2b4, sgnl_p2b3, sgnl_p2b2, sgnl_p2b1, sgnl_p2f1, sgnl_p2f2, sgnl_p2f3, sgnl_p2f4, sgnl_p2f5
#
#     del trgt
#
#     del sr_p1
#     del sr_p1b5, sr_p1b4, sr_p1b3, sr_p1b2, sr_p1b1, sr_p1f1, sr_p1f2, sr_p1f3, sr_p1f4, sr_p1f5
#     del sr_p1std, sr_p1med, sr_p1q10, sr_p1q90
#     del sr_p1fbr0, sr_p1fbr1, sr_p1fbr2, sr_p1fbr3, sr_p1fbr4, sr_p1fbr5, sr_p1fbr6, sr_p1fbr7, sr_p1fbr8
#     del sr_p1_b3f3_b2f2_b1f1, sr_p1_b3f1_b2f2_b1f3
#     del sr_p2
#     del sr_p2b5, sr_p2b4, sr_p2b3, sr_p2b2, sr_p2b1, sr_p2f1, sr_p2f2, sr_p2f3, sr_p2f4, sr_p2f5
#     del sr_p1b5_p2f5, sr_p1b3_p2f3, sr_p1b1_p2f1, sr_p1f1_p2b1, sr_p1f3_p2b3, sr_p1f5_p2b5
#     del sr_p2b5_p1favg, sr_p2b3_p1favg, sr_p2b1_p1favg, sr_p2f5_p1bavg, sr_p2f3_p1bavg, sr_p2f1_p1bavg
#     del sr, tr

# %% [raw]
# for i in tqdm(range(0, 10)):
#     sgnl_ndcs = batch_id_trn[i]
#
#     trgt = pdf_trn['open_channels'].iloc[sgnl_ndcs]
#
#     # ------------------------------------------------
#     sgnl_p1 = pdf_trn['signal_norm'].iloc[sgnl_ndcs]
#
#     sgnl_p1b5 = sgnl_p1.shift(-5, fill_value=fill)
#     sgnl_p1b4 = sgnl_p1.shift(-4, fill_value=fill)
#     sgnl_p1b3 = sgnl_p1.shift(-3, fill_value=fill)
#     sgnl_p1b2 = sgnl_p1.shift(-2, fill_value=fill)
#     sgnl_p1b1 = sgnl_p1.shift(-1, fill_value=fill)
#     sgnl_p1f1 = sgnl_p1.shift(1, fill_value=fill)
#     sgnl_p1f2 = sgnl_p1.shift(2, fill_value=fill)
#     sgnl_p1f3 = sgnl_p1.shift(3, fill_value=fill)
#     sgnl_p1f4 = sgnl_p1.shift(4, fill_value=fill)
#     sgnl_p1f5 = sgnl_p1.shift(5, fill_value=fill)
#
#     sgnl_stck0 = np.stack([sgnl_p1b5, sgnl_p1b4, sgnl_p1b3, sgnl_p1b2, sgnl_p1b1, sgnl_p1, sgnl_p1f1, sgnl_p1f2, sgnl_p1f3, sgnl_p1f4, sgnl_p1f5])
#     sgnl_stckb = np.stack([sgnl_p1b5, sgnl_p1b4, sgnl_p1b3, sgnl_p1b2, sgnl_p1b1])
#     sgnl_stckf = np.stack([sgnl_p1f1, sgnl_p1f2, sgnl_p1f3, sgnl_p1f4, sgnl_p1f5])
#
#     sgnl_std = pd.Series(np.std(sgnl_stck0, 0))
#     sgnl_med = pd.Series(np.median(sgnl_stck0, 0))
#     sgnl_q10 = pd.Series(np.quantile(sgnl_stck0, 0.1, 0))
#     sgnl_q90 = pd.Series(np.quantile(sgnl_stck0, 0.9, 0))
#     sgnl_fb_ratio0 = pd.Series(sgnl_stckf.sum(0) / sgnl_stckb.sum(0))
#     sgnl_fb_ratio1 = pd.Series(np.max(sgnl_stckf, 0) / np.max(sgnl_stckb, 0))
#     sgnl_fb_ratio2 = pd.Series(np.max(sgnl_stckf, 0) / np.min(sgnl_stckb, 0))
#     sgnl_fb_ratio3 = pd.Series(np.min(sgnl_stckf, 0) / np.max(sgnl_stckb, 0))
#     sgnl_fb_ratio4 = pd.Series(np.median(sgnl_stckf, 0) / np.median(sgnl_stckb, 0))
#     sgnl_fb_ratio5 = pd.Series(np.quantile(sgnl_stckf, 0.1, 0) / np.quantile(sgnl_stckb, 0.1, 0))
#     sgnl_fb_ratio6 = pd.Series(np.quantile(sgnl_stckf, 0.9, 0) / np.quantile(sgnl_stckb, 0.9, 0))
#     sgnl_fb_ratio7 = pd.Series(np.quantile(sgnl_stckf, 0.9, 0) / np.quantile(sgnl_stckb, 0.1, 0))
#     sgnl_fb_ratio8 = pd.Series(np.quantile(sgnl_stckf, 0.1, 0) / np.quantile(sgnl_stckb, 0.9, 0))
#
#     sr_p1b5 = ts_utils.serie_stacker(sgnl_p1b5, step_size=step, block_size=wndw); sr_p1b5 = (sr_p1b5 - sr_p1b5.mean()) / sr_p1b5.std()
#     sr_p1b4 = ts_utils.serie_stacker(sgnl_p1b4, step_size=step, block_size=wndw); sr_p1b4 = (sr_p1b4 - sr_p1b4.mean()) / sr_p1b4.std()
#     sr_p1b3 = ts_utils.serie_stacker(sgnl_p1b3, step_size=step, block_size=wndw); sr_p1b3 = (sr_p1b3 - sr_p1b3.mean()) / sr_p1b3.std()
#     sr_p1b2 = ts_utils.serie_stacker(sgnl_p1b2, step_size=step, block_size=wndw); sr_p1b2 = (sr_p1b2 - sr_p1b2.mean()) / sr_p1b2.std()
#     sr_p1b1 = ts_utils.serie_stacker(sgnl_p1b1, step_size=step, block_size=wndw); sr_p1b1 = (sr_p1b1 - sr_p1b1.mean()) / sr_p1b1.std()
#     sr_p1  = ts_utils.serie_stacker(sgnl_p1, step_size=step, block_size=wndw); sr_p1 = (sr_p1 - sr_p1.mean()) / sr_p1.std()
#     sr_p1f1 = ts_utils.serie_stacker(sgnl_p1f1, step_size=step, block_size=wndw); sr_p1f1 = (sr_p1f1 - sr_p1f1.mean()) / sr_p1f1.std()
#     sr_p1f2 = ts_utils.serie_stacker(sgnl_p1f2, step_size=step, block_size=wndw); sr_p1f2 = (sr_p1f2 - sr_p1f2.mean()) / sr_p1f2.std()
#     sr_p1f3 = ts_utils.serie_stacker(sgnl_p1f3, step_size=step, block_size=wndw); sr_p1f3 = (sr_p1f3 - sr_p1f3.mean()) / sr_p1f3.std()
#     sr_p1f4 = ts_utils.serie_stacker(sgnl_p1f4, step_size=step, block_size=wndw); sr_p1f4 = (sr_p1f4 - sr_p1f4.mean()) / sr_p1f4.std()
#     sr_p1f5 = ts_utils.serie_stacker(sgnl_p1f5, step_size=step, block_size=wndw); sr_p1f5 = (sr_p1f5 - sr_p1f5.mean()) / sr_p1f5.std()
#
#     sr_p1_b3f3_b2f2_b1f1  = ts_utils.serie_stacker(
#         sgnl_p1b3*sgnl_p1f3+sgnl_p1b2*sgnl_p1f2+sgnl_p1b1*sgnl_p1f1,
#         step_size=step,
#         block_size=wndw
#     )
#     sr_p1_b3f3_b2f2_b1f1 = (sr_p1_b3f3_b2f2_b1f1 - sr_p1_b3f3_b2f2_b1f1.mean()) / sr_p1_b3f3_b2f2_b1f1.std()
#
#     sr_p1_b3f1_b2f2_b1f3  = ts_utils.serie_stacker(
#         sgnl_p1b3*sgnl_p1f1-sgnl_p1b2*sgnl_p1f2+sgnl_p1b1*sgnl_p1f3,
#         step_size=step,
#         block_size=wndw
#     )
#     sr_p1_b3f1_b2f2_b1f3 = (sr_p1_b3f1_b2f2_b1f3 - sr_p1_b3f1_b2f2_b1f3.mean()) / sr_p1_b3f1_b2f2_b1f3.std()
#
#     sr_p1std = ts_utils.serie_stacker(sgnl_std, step_size=step, block_size=wndw); sr_p1std = (sr_p1std - sr_p1std.mean()) / sr_p1std.std()
#     sr_p1med = ts_utils.serie_stacker(sgnl_med, step_size=step, block_size=wndw); sr_p1med = (sr_p1med - sr_p1med.mean()) / sr_p1med.std()
#     sr_p1q10 = ts_utils.serie_stacker(sgnl_q10, step_size=step, block_size=wndw); sr_p1q10 = (sr_p1q10 - sr_p1q10.mean()) / sr_p1q10.std()
#     sr_p1q90 = ts_utils.serie_stacker(sgnl_q90, step_size=step, block_size=wndw); sr_p1q90 = (sr_p1q90 - sr_p1q90.mean()) / sr_p1q90.std()
#     sr_p1fbr0 = ts_utils.serie_stacker(sgnl_fb_ratio0, step_size=step, block_size=wndw); sr_p1fbr0 = (sr_p1fbr0 - sr_p1fbr0.mean()) / sr_p1fbr0.std()
#     sr_p1fbr1 = ts_utils.serie_stacker(sgnl_fb_ratio1, step_size=step, block_size=wndw); sr_p1fbr1 = (sr_p1fbr1 - sr_p1fbr1.mean()) / sr_p1fbr1.std()
#     sr_p1fbr2 = ts_utils.serie_stacker(sgnl_fb_ratio2, step_size=step, block_size=wndw); sr_p1fbr2 = (sr_p1fbr2 - sr_p1fbr2.mean()) / sr_p1fbr2.std()
#     sr_p1fbr3 = ts_utils.serie_stacker(sgnl_fb_ratio3, step_size=step, block_size=wndw); sr_p1fbr3 = (sr_p1fbr3 - sr_p1fbr3.mean()) / sr_p1fbr3.std()
#     sr_p1fbr4 = ts_utils.serie_stacker(sgnl_fb_ratio4, step_size=step, block_size=wndw); sr_p1fbr4 = (sr_p1fbr4 - sr_p1fbr4.mean()) / sr_p1fbr4.std()
#     sr_p1fbr5 = ts_utils.serie_stacker(sgnl_fb_ratio5, step_size=step, block_size=wndw); sr_p1fbr5 = (sr_p1fbr5 - sr_p1fbr5.mean()) / sr_p1fbr5.std()
#     sr_p1fbr6 = ts_utils.serie_stacker(sgnl_fb_ratio6, step_size=step, block_size=wndw); sr_p1fbr6 = (sr_p1fbr6 - sr_p1fbr6.mean()) / sr_p1fbr6.std()
#     sr_p1fbr7 = ts_utils.serie_stacker(sgnl_fb_ratio7, step_size=step, block_size=wndw); sr_p1fbr7 = (sr_p1fbr7 - sr_p1fbr7.mean()) / sr_p1fbr7.std()
#     sr_p1fbr8 = ts_utils.serie_stacker(sgnl_fb_ratio8, step_size=step, block_size=wndw); sr_p1fbr8 = (sr_p1fbr8 - sr_p1fbr8.mean()) / sr_p1fbr8.std()
#
#     # ------------------------------------------------
#     sgnl_p2 = sgnl_p1**2
#
#     sgnl_p2b5 = sgnl_p2.shift(-5, fill_value=fill)
#     sgnl_p2b4 = sgnl_p2.shift(-4, fill_value=fill)
#     sgnl_p2b3 = sgnl_p2.shift(-3, fill_value=fill)
#     sgnl_p2b2 = sgnl_p2.shift(-2, fill_value=fill)
#     sgnl_p2b1 = sgnl_p2.shift(-1, fill_value=fill)
#     sgnl_p2f1 = sgnl_p2.shift(1, fill_value=fill)
#     sgnl_p2f2 = sgnl_p2.shift(2, fill_value=fill)
#     sgnl_p2f3 = sgnl_p2.shift(3, fill_value=fill)
#     sgnl_p2f4 = sgnl_p2.shift(4, fill_value=fill)
#     sgnl_p2f5 = sgnl_p2.shift(5, fill_value=fill)
#
#     sr_p2b5 = ts_utils.serie_stacker(sgnl_p2b5, step_size=step, block_size=wndw); sr_p2b5 = (sr_p2b5 - sr_p2b5.mean()) / sr_p2b5.std()
#     sr_p2b4 = ts_utils.serie_stacker(sgnl_p2b4, step_size=step, block_size=wndw); sr_p2b4 = (sr_p2b4 - sr_p2b4.mean()) / sr_p2b4.std()
#     sr_p2b3 = ts_utils.serie_stacker(sgnl_p2b3, step_size=step, block_size=wndw); sr_p2b3 = (sr_p2b3 - sr_p2b3.mean()) / sr_p2b3.std()
#     sr_p2b2 = ts_utils.serie_stacker(sgnl_p2b2, step_size=step, block_size=wndw); sr_p2b2 = (sr_p2b2 - sr_p2b2.mean()) / sr_p2b2.std()
#     sr_p2b1 = ts_utils.serie_stacker(sgnl_p2b1, step_size=step, block_size=wndw); sr_p2b1 = (sr_p2b1 - sr_p2b1.mean()) / sr_p2b1.std()
#     sr_p2  = ts_utils.serie_stacker(sgnl_p2, step_size=step, block_size=wndw); sr_p2 = (sr_p2 - sr_p2.mean()) / sr_p2.std()
#     sr_p2f1 = ts_utils.serie_stacker(sgnl_p2f1, step_size=step, block_size=wndw); sr_p2f1 = (sr_p2f1 - sr_p2f1.mean()) / sr_p2f1.std()
#     sr_p2f2 = ts_utils.serie_stacker(sgnl_p2f2, step_size=step, block_size=wndw); sr_p2f2 = (sr_p2f2 - sr_p2f2.mean()) / sr_p2f2.std()
#     sr_p2f3 = ts_utils.serie_stacker(sgnl_p2f3, step_size=step, block_size=wndw); sr_p2f3 = (sr_p2f3 - sr_p2f3.mean()) / sr_p2f3.std()
#     sr_p2f4 = ts_utils.serie_stacker(sgnl_p2f4, step_size=step, block_size=wndw); sr_p2f4 = (sr_p2f4 - sr_p2f4.mean()) / sr_p2f4.std()
#     sr_p2f5 = ts_utils.serie_stacker(sgnl_p2f5, step_size=step, block_size=wndw); sr_p2f5 = (sr_p2f5 - sr_p2f5.mean()) / sr_p2f5.std()
#
#     sr_p1b5_p2f5 = ts_utils.serie_stacker((sgnl_p1b5+sgnl_p2f5)/sgnl_p2, step_size=step, block_size=wndw); sr_p1b5_p2f5 = (sr_p1b5_p2f5 - sr_p1b5_p2f5.mean()) / sr_p1b5_p2f5.std()
#     sr_p1b3_p2f3 = ts_utils.serie_stacker((sgnl_p1b3+sgnl_p2f3)/sgnl_p2, step_size=step, block_size=wndw); sr_p1b3_p2f3 = (sr_p1b3_p2f3 - sr_p1b3_p2f3.mean()) / sr_p1b3_p2f3.std()
#     sr_p1b1_p2f1 = ts_utils.serie_stacker((sgnl_p1b1+sgnl_p2f1)/sgnl_p2, step_size=step, block_size=wndw); sr_p1b1_p2f1 = (sr_p1b1_p2f1 - sr_p1b1_p2f1.mean()) / sr_p1b1_p2f1.std()
#     sr_p1f1_p2b1 = ts_utils.serie_stacker((sgnl_p1f1-sgnl_p2b1)/sgnl_p2, step_size=step, block_size=wndw); sr_p1f1_p2b1 = (sr_p1f1_p2b1 - sr_p1f1_p2b1.mean()) / sr_p1f1_p2b1.std()
#     sr_p1f3_p2b3 = ts_utils.serie_stacker((sgnl_p1f3-sgnl_p2b3)/sgnl_p2, step_size=step, block_size=wndw); sr_p1f3_p2b3 = (sr_p1f3_p2b3 - sr_p1f3_p2b3.mean()) / sr_p1f3_p2b3.std()
#     sr_p1f5_p2b5 = ts_utils.serie_stacker((sgnl_p1f5-sgnl_p2b5)/sgnl_p2, step_size=step, block_size=wndw); sr_p1f5_p2b5 = (sr_p1f5_p2b5 - sr_p1f5_p2b5.mean()) / sr_p1f5_p2b5.std()
#
#     sr_p2b5_p1favg = ts_utils.serie_stacker(sgnl_p2b5-sgnl_stckf.mean(0), step_size=step, block_size=wndw); sr_p2b5_p1favg = (sr_p2b5_p1favg - sr_p2b5_p1favg.mean()) / sr_p2b5_p1favg.std()
#     sr_p2b3_p1favg = ts_utils.serie_stacker(sgnl_p2b3-sgnl_stckf.mean(0), step_size=step, block_size=wndw); sr_p2b3_p1favg = (sr_p2b3_p1favg - sr_p2b3_p1favg.mean()) / sr_p2b3_p1favg.std()
#     sr_p2b1_p1favg = ts_utils.serie_stacker(sgnl_p2b1-sgnl_stckf.mean(0), step_size=step, block_size=wndw); sr_p2b1_p1favg = (sr_p2b1_p1favg - sr_p2b1_p1favg.mean()) / sr_p2b1_p1favg.std()
#     sr_p2f5_p1bavg = ts_utils.serie_stacker(sgnl_p2f5-sgnl_stckb.mean(0), step_size=step, block_size=wndw); sr_p2f5_p1bavg = (sr_p2f5_p1bavg - sr_p2f5_p1bavg.mean()) / sr_p2f5_p1bavg.std()
#     sr_p2f3_p1bavg = ts_utils.serie_stacker(sgnl_p2f3-sgnl_stckb.mean(0), step_size=step, block_size=wndw); sr_p2f3_p1bavg = (sr_p2f3_p1bavg - sr_p2f3_p1bavg.mean()) / sr_p2f3_p1bavg.std()
#     sr_p2f1_p1bavg = ts_utils.serie_stacker(sgnl_p2f1-sgnl_stckb.mean(0), step_size=step, block_size=wndw); sr_p2f1_p1bavg = (sr_p2f1_p1bavg - sr_p2f1_p1bavg.mean()) / sr_p2f1_p1bavg.std()
#     #break
#     sr = np.stack(
#         [
#             sr_p1,
#             sr_p1b5, sr_p1b4, sr_p1b3, sr_p1b2, sr_p1b1, sr_p1f1, sr_p1f2, sr_p1f3, sr_p1f4, sr_p1f5,
#             sr_p1std, sr_p1med, sr_p1q10, sr_p1q90,
#             sr_p1fbr0, sr_p1fbr1, sr_p1fbr2, sr_p1fbr3, sr_p1fbr4, sr_p1fbr5, sr_p1fbr6, sr_p1fbr7, sr_p1fbr8,
#             sr_p1_b3f3_b2f2_b1f1, sr_p1_b3f1_b2f2_b1f3,
#             sr_p2,
#             sr_p2b5, sr_p2b4, sr_p2b3, sr_p2b2, sr_p2b1, sr_p2f1, sr_p2f2, sr_p2f3, sr_p2f4, sr_p2f5,
#             sr_p1b5_p2f5, sr_p1b3_p2f3, sr_p1b1_p2f1, sr_p1f1_p2b1, sr_p1f3_p2b3, sr_p1f5_p2b5,
#             sr_p2b5_p1favg, sr_p2b3_p1favg, sr_p2b1_p1favg, sr_p2f5_p1bavg, sr_p2f3_p1bavg, sr_p2f1_p1bavg,
#         ],
#         axis=2
#     )
#
#     tr = ts_utils.serie_stacker(trgt, step_size=step, block_size=wndw)
#     break
#     bp.pack_ndarray_to_file(sr, '../input/trn_srs_dat_g{:d}_s{:d}_w{:d}_feat_v1.bp'.format(i, step, wndw))
#     bp.pack_ndarray_to_file(tr, '../input/trn_srs_lbl_g{:d}_s{:d}_w{:d}_feat_v1.bp'.format(i, step, wndw))
#
#     del sgnl_ndcs
#
#     del sgnl_p1, sgnl_p2
#     del sgnl_p1b5, sgnl_p1b4, sgnl_p1b3, sgnl_p1b2, sgnl_p1b1, sgnl_p1f1, sgnl_p1f2, sgnl_p1f3, sgnl_p1f4, sgnl_p1f5
#     del sgnl_stck0
#     del sgnl_stckb, sgnl_stckf
#     del sgnl_std, sgnl_med, sgnl_q10, sgnl_q90
#     del sgnl_fb_ratio0, sgnl_fb_ratio1, sgnl_fb_ratio2, sgnl_fb_ratio3, sgnl_fb_ratio4, sgnl_fb_ratio5, sgnl_fb_ratio6, sgnl_fb_ratio7, sgnl_fb_ratio8
#     del sgnl_p2b5, sgnl_p2b4, sgnl_p2b3, sgnl_p2b2, sgnl_p2b1, sgnl_p2f1, sgnl_p2f2, sgnl_p2f3, sgnl_p2f4, sgnl_p2f5
#
#     del trgt
#
#     del sr_p1
#     del sr_p1b5, sr_p1b4, sr_p1b3, sr_p1b2, sr_p1b1, sr_p1f1, sr_p1f2, sr_p1f3, sr_p1f4, sr_p1f5
#     del sr_p1std, sr_p1med, sr_p1q10, sr_p1q90
#     del sr_p1fbr0, sr_p1fbr1, sr_p1fbr2, sr_p1fbr3, sr_p1fbr4, sr_p1fbr5, sr_p1fbr6, sr_p1fbr7, sr_p1fbr8
#     del sr_p1_b3f3_b2f2_b1f1, sr_p1_b3f1_b2f2_b1f3
#     del sr_p2
#     del sr_p2b5, sr_p2b4, sr_p2b3, sr_p2b2, sr_p2b1, sr_p2f1, sr_p2f2, sr_p2f3, sr_p2f4, sr_p2f5
#     del sr_p1b5_p2f5, sr_p1b3_p2f3, sr_p1b1_p2f1, sr_p1f1_p2b1, sr_p1f3_p2b3, sr_p1f5_p2b5
#     del sr_p2b5_p1favg, sr_p2b3_p1favg, sr_p2b1_p1favg, sr_p2f5_p1bavg, sr_p2f3_p1bavg, sr_p2f1_p1bavg
#     del sr, tr

# %% [raw]
# dat_fs = sorted([f for f in os.listdir('../input/') if ('trn_srs_dat' in f) and ('s2000' in f) and ('w4000 in f')])
# lbl_fs = sorted([f for f in os.listdir('../input/') if ('trn_srs_lbl' in f) and ('s2000' in f) and ('w4000 in f')])
#
# series_dat = np.concatenate(
#     [bp.unpack_ndarray_from_file(os.path.join('../input/', f)) for f in dat_fs],
#     axis=0
# )
#
# series_lbl = [bp.unpack_ndarray_from_file(os.path.join('../input/', f)) for f in lbl_fs]
#
# series_grp = np.concatenate(
#     [np.ones(shape=(arr.shape[0],)) * i for i, arr in zip(range(10), series_lbl)],
#     axis=0
# ).astype(int)
#
# series_lbl = np.concatenate(
#     series_lbl,
#     axis=0
# )[:, :, None]

# %% [raw]
# feat_func_list = [
#     g_utils.named_partial(
#         ts_utils.serie_stacker,
#         step_size=100,
#         block_size=wndw,
#     )
# ]

# %% [raw]
# def runner(ndx, serie, period):
#     sr_slice = serie.iloc[ndx:ndx+period]
#     # get feature and name
#     feat, dat = ts_utils.feature_runner(sr_slice, feat_func_list)
#     # collect label
#     lbl = trgt.iloc[ndx]
#     return feat, dat, lbl, ndx

# %% [raw]
# feat_func_list = [
#     g_utils.named_partial(
#         ts_utils.serie_stacker,
#         step_size=100,
#         block_size=wndw,
#         feature_extractor=[
#             maximum,
#             minimum,
#             standard_dev,
#             np.median,
#             pctl1,
#             pctl10,
#             pctl50,
#             pctl90,
#             pctl99,
#         ],
#     )
# ]
